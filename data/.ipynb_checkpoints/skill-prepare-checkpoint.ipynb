# %%
import pandas as pd
import numpy as np
df = pd.read_csv('dataset/marketing_sample_for_naukri_com-jobs__20190701_20190830__30k_data.csv')

# %% [markdown]
# # Dataset Preparation

# %% [markdown]
# ### Drop unused columns

# %%
df = df.drop(['Uniq Id', 
              'Crawl Timestamp', 
              'Job Salary', 
              'Job Experience Required', 
              'Location', 
              'Functional Area', 
              'Industry'], axis=1)

# %% [markdown]
# ### Drop rows which are not the "Programming & Design" category
# note that, "category" = "role" in dataset

# %%
df = df.drop(df[(df['Role Category'] != 'Programming & Design')].index)

### After that, drop "Role Category" column
df = df.drop('Role Category', axis=1)
df = df.dropna()

# %% [markdown]
# ### Trim and split Job Title, Key Skills

# %%
df['Job Title'] = df['Job Title'].str.strip()
df['Key Skills'] = df['Key Skills'].str.strip()
df['Key Skills'] = df['Key Skills'].str.split("|")

# %%
### Display all categories
df['Role'].unique()
# Out:
# array(['Testing Engineer', 'System Analyst', 'Technical Architect',
#        'Software Developer', 'Graphic/Web Designer', 'Project Lead',
#        'Team Lead/Technical Lead', 'Release Manager', 'Product Manager',
#        'Database Architect/Designer'], dtype=object)

# %%
### reset dataframe index after everything done
df = df.reset_index(drop=True)

df.head()
# Out:
#                                            Job Title  \
# 0                  Software Test Engineer -hyderabad
# 1             Opening For Adobe Analytics Specialist
# 2  Opportunity For Azure Devops Architect For Hyd...
# 3                                        Oracle IDAM
# 4                                  Magento Developer
#
#                                           Key Skills                 Role
# 0  [manual testing,  test engineering,  test case...     Testing Engineer
# 1  [adobe experience manager,  digital,  digital ...       System Analyst
# 2  [TFS,  Azure,  Git,  VSTS,  Docker,  DynaTrace...  Technical Architect
# 3                            [Oracle IDAM, OIM, OAM]   Software Developer
# 4  [Copyright,  Email,  jQuery,  XML,  Javascript...   Software Developer

# %% [markdown]
# ## Initial values

# %%
roles = ['Testing Engineer',
         'System Analyst',
         'Technical Architect',
         'Software Developer',
         'Graphic/Web Designer',
         'Project Lead',
         'Team Lead/Technical Lead',
#          'Release Manager',
         'Product Manager',
         'Database Architect/Designer']

categories = ['cate_data', 
              'cate_developer', 
              'cate_tester', 
              'cate_design', 
              'cate_manager', 
              'cate_analyst']

cate_data = ['Data Engineer',
             'Data Scientist',
             'Data Architect',
             'Data Analyst',
             'Database Administrator',
             'Machine Learning']

cate_developer = ['Software Engineer',
                  'Devops',
                  'Backend',
                  'Frontend',
                  'Full stack',
                  'iOS',
                  'Android']

cate_tester = ['Software Tester',
               'Quality Assurance Engineer']

cate_design = ['UX/UI Designer',
               'Graphic Designer']

cate_manager = ['Product Owner',
                'Project Manager']

cate_analyst = ['System Analyst',
                'Business Analyst']

forbidden_skills = ['development',
                    'design',
                    'web',
                    'css3',
                    'html5',
                    'operations',
                    'management',
                    'project leader',
                    'architect',
                    'architecture',
                    'testing',
                    'software',
                    'tools',
                    'quality',
                    'support',
                    'application',
                    'applications',
                    'developer',
                    'technical',
                    'automation',
                    'graphics',
                    'phd',
                    'email',
                    'apple',
                    'research',
                    'iphone',
                    'ipad']

# %% [markdown]
# ## Extract Key Skills function
# count skills by given set of "Key Skills" in job's dataframe

# %%
#
##
### input like this -> extractSkill(dataframe['Key Skills'])
##
#

def extractSkill(df):

    ### trim each Key Skill in each Title
    vowel = []
    for x in df:
        for i in range(len(x)):
            vowel.append(x[i].strip().lower())

    ### Counting elements
    elements_count = {}
    # iterating over the elements for frequency
    for element in vowel:
        # checking whether it is in the dict or not
        if element in elements_count:
            # incerementing the count by 1
            elements_count[element] += 1
        else:
            # setting the count to 1
            elements_count[element] = 1
        
    elements_count = dict(sorted(elements_count.items(), key=lambda item: item[1], reverse=True))

#     # printing the elements frequencies
#     for key, value in elements_count.items():
#         print(f"{key}: {value}")
        
    return elements_count

# %% [markdown]
# ## Replace and Remove Skills function
# input: dataframe with "skill" and "sum" columns

# %%
def cleanSkillKeywords(df):
    df = df.drop(df[(df['sum'] == 1)].index)
    
    df.loc[(df['skill'] == "Programming"), "skill"] = "coding"
    
    df.loc[(df['skill'] == "test automation"), "skill"] = "automation testing"
    
    df.loc[(df['skill'] == "data scientist"), "skill"] = "data science"
    
    df.loc[(df['skill'] == "asp") | 
           (df['skill'] == "asp.net") | 
           (df['skill'] == "asp.net mvc"), "skill"] = ".net"
    
    df.loc[(df['skill'] == "natural language processing"), "skill"] = "nlp"
    
    df.loc[(df['skill'] == "advanced analytics") | 
           (df['skill'] == "analytical") | 
           (df['skill'] == "analyst"), "skill"] = "analytics"
    
    df.loc[(df['skill'] == "front end"), "skill"] = "frontend"
    
    df.loc[(df['skill'] == "web technologies") | 
           (df['skill'] == "web application development") | 
           (df['skill'] == "web application"), "skill"] = "web development"
    
    df.loc[(df['skill'] == "ios"), "skill"] = "ios development"
    
    df.loc[(df['skill'] == "android") | 
           (df['skill'] == "android application development") | 
           (df['skill'] == "android application"), "skill"] = "android development"
    
    df.loc[(df['skill'] == "mobile") | 
           (df['skill'] == "mobile application") | 
           (df['skill'] == "mobile development") | 
           (df['skill'] == "mobile applications"), "skill"] = "mobile application development"
    
    df.loc[(df['skill'] == "user interface designing") | 
           (df['skill'] == "ui") | 
           (df['skill'] == "ui designer") | 
           (df['skill'] == "user interface") | 
           (df['skill'] == "user interface designer"), "skill"] = "ui designing"
    
    df.loc[(df['skill'] == "ux designer") | 
           (df['skill'] == "ux") | 
           (df['skill'] == "user experience"), "skill"] = "ux designing"
    
    df.loc[(df['skill'] == "graphic designer"), "skill"] = "graphic designing"
    
    df.loc[(df['skill'] == "product manager"), "skill"] = "product management"
    
    df = df[~df['skill'].isin(forbidden_skills)]
    
    df = df.groupby('skill')['sum'].agg(['sum']).sort_values(by=['sum'], ascending=False).reset_index() 
    
    return df

# %% [markdown]
# ## Match between Jobs function
# method: set or sort<br>
# percent: integer (0 -> 100)

# %%
from fuzzywuzzy import fuzz

def matchJobs(title, method, percent):
    
    def get_ratio_token_set(df):
        df_column = df['Job Title']
        return fuzz.token_set_ratio(title, df_column)
    
    def get_ratio_token_sort(df):
        df_column = df['Job Title']
        return fuzz.token_sort_ratio(title, df_column)

    if method == "set":
        match_data = df[df.apply(get_ratio_token_set, axis=1) >= percent]
    elif method == "sort":
        match_data = df[df.apply(get_ratio_token_sort, axis=1) >= percent]
        
    return match_data

# %% [markdown]
# # Job Skills

# %%
df_match = matchJobs(title="Product Owner", method="set", percent=90)
list_match = extractSkill(df_match['Key Skills'])
df_recommend = pd.DataFrame(list_match.items(), columns = ['skill', 'sum'])
df_recommend = cleanSkillKeywords(df_recommend)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df_recommend)
# Out:
#                  skill  sum
# 0                agile    6
# 1                scrum    4
# 2   product management    4
# 3                 jira    3
# 4           monitoring    3
# 5            analytics    3
# 6     computer science    3
# 7              telecom    2
# 8     product strategy    2
# 9                  pdf    2
# 10         action plan    2
# 11     market research    2
# 12                 hrm    2
# 13  design development    2
# 14             billing    2
# 15         agile scrum    2
# 16   agile development    2
# 17        user stories    2

# %% [markdown]
# ### Export every jobs to .csv

# %%
for category in categories:
    for job in eval(category):

        df_match = matchJobs(title=job, method="set", percent=90)
        
        list_match = extractSkill(df_match['Key Skills'])
        df_recommend = pd.DataFrame(list_match.items(), columns = ['skill', 'sum']) 
        df_recommend = cleanSkillKeywords(df_recommend)
        
#         with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#             display(df_recommend)
        job_path = job.replace("/", ":")
        df_recommend.to_csv('exports/jobskill/' + category + '_' + job_path + '.csv', index=True)

# %% [markdown]
# # Category Skill (New)

# %%
df_category_skill = pd.DataFrame(columns = ['skill', 'sum'])

for job in cate_developer:
    
    df_match = matchJobs(title=job, method="set", percent=90)

    list_match = extractSkill(df_match['Key Skills'])
    df_cat = pd.DataFrame(list_match.items(), columns = ['skill', 'sum']) 
    df_cat = df_cat.drop(df_cat[(df_cat['sum'] == 1)].index)
    df_cat = cleanSkillKeywords(df_cat)
    df_cat = df_cat.groupby('skill')['sum'].agg(['sum']).reset_index() 
    df_category_skill = df_category_skill.append(df_cat)

df_category_skill = df_category_skill.groupby('skill')['sum'].agg(['sum','count']).sort_values(by=['count', 'sum'], ascending=False).reset_index()
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df_category_skill)
    
# df_category_skill.to_csv('out.csv', index=True)
# Out:
#                                   skill  sum  count
# 0                            javascript  398      7
# 1                                  java  286      7
# 2                                   sql  198      7
# 3                                 mysql  175      7
# 4                                 agile  123      7
# 5                                   git  115      7
# 6                             debugging   99      7
# 7                                  rest   82      7
# 8                                   api   46      7
# 9                                python  236      6
# 10                                 html  218      6
# 11                                linux  171      6
# 12                      web development  171      6
# 13                               jquery  164      6
# 14                     computer science  159      6
# 15                                 .net  154      6
# 16                                  xml  152      6
# 17                                 json  144      6
# 18                                  c++  117      6
# 19                               coding  115      6
# 20                          programming  111      6
# 21                                  css  107      6
# 22                                 ajax  105      6
# 23                                  php   85      6
# 24                             frontend   82      6
# 25                 software development   77      6
# 26                              backend   76      6
# 27                         unit testing   73      6
# 28                               oracle   68      6
# 29                          open source   64      6
# 30                                cloud   58      6
# 31                             database   42      6
# 32                              service   31      6
# 33                  android development  251      5
# 34                                    c  146      5
# 35                      data structures  112      5
# 36                            analytics   96      5
# 37                            core java   93      5
# 38                                  mvc   89      5
# 39                         web services   82      5
# 40                                 j2ee   80      5
# 41                                   c#   73      5
# 42                              mongodb   70      5
# 43                      design patterns   59      5
# 44                                 oops   57      5
# 45              application development   55      5
# 46                           algorithms   54      5
# 47                              windows   53      5
# 48                           networking   49      5
# 49                                   it   47      5
# 50                                rdbms   42      5
# 51                                   ui   42      5
# 52                                 http   36      5
# 53                                scrum   36      5
# 54                       multithreading   35      5
# 55                       data structure   25      5
# 56             user interface designing   25      5
# 57               continuous integration   22      5
# 58               information technology   22      5
# 59                      version control   20      5
# 60                                  svn   17      5
# 61                      ios development  174      4
# 62       mobile application development  152      4
# 63                 software engineering   97      4
# 64                            angularjs   93      4
# 65                                  aws   80      4
# 66                              node.js   70      4
# 67                               devops   69      4
# 68                             react.js   64      4
# 69                                 unix   60      4
# 70                                nosql   55      4
# 71                               sqlite   52      4
# 72                              jenkins   50      4
# 73                               docker   42      4
# 74                      software design   42      4
# 75                                maven   40      4
# 76                   performance tuning   40      4
# 77                               server   35      4
# 78                           sql server   35      4
# 79                            bootstrap   33      4
# 80                                 sdlc   33      4
# 81                               apache   32      4
# 82                              eclipse   31      4
# 83                                 jira   31      4
# 84                                   ux   31      4
# 85                           developing   30      4
# 86                                 ruby   30      4
# 87                                  soa   29      4
# 88                    assembly language   28      4
# 89                           consulting   22      4
# 90                                level   22      4
# 91                            algorithm   21      4
# 92                           deployment   21      4
# 93                   design development   20      4
# 94                       infrastructure   20      4
# 95                            six sigma   20      4
# 96                   project management   19      4
# 97                          recruitment   19      4
# 98                            cassandra   17      4
# 99                                  pmp   17      4
# 100                              github   15      4
# 101                         webservices   12      4
# 102                           hibernate   77      3
# 103                         android sdk   72      3
# 104                         objective c   71      3
# 105                              spring   62      3
# 106                                 sdk   55      3
# 107                     troubleshooting   44      3
# 108                                perl   41      3
# 109                          test cases   34      3
# 110                              django   31      3
# 111                          postgresql   31      3
# 112                               xcode   31      3
# 113                       microservices   30      3
# 114                         spring boot   30      3
# 115                                 wcf   28      3
# 116                 distribution system   25      3
# 117                              struts   25      3
# 118                  business executive   23      3
# 119                                soap   23      3
# 120                                jdbc   22      3
# 121         object oriented programming   22      3
# 122                          healthcare   21      3
# 123                                ooad   21      3
# 124                     database design   20      3
# 125                              tomcat   20      3
# 126                                 uml   20      3
# 127                   agile methodology   19      3
# 128                               azure   19      3
# 129                   memory management   16      3
# 130                                mvvm   15      3
# 131                   agile development   14      3
# 132                                 mca   14      3
# 133                               redis   14      3
# 134                                 tdd   14      3
# 135                               jboss   13      3
# 136                               junit   13      3
# 137                  software developer   13      3
# 138                               solid   13      3
# 139                       ruby on rails   12      3
# 140                        social media   12      3
# 141                           wordpress   12      3
# 142                                 jms   11      3
# 143                          middleware   11      3
# 144         real time operating systems   10      3
# 145             test driven development   10      3
# 146                           usability   10      3
# 147                             cakephp    9      3
# 148                       data modeling    9      3
# 149                           photoshop    9      3
# 150                  release management    9      3
# 151                                 san    9      3
# 152                    spring framework    9      3
# 153                                 tfs    9      3
# 154                         scalability    8      3
# 155                                 ssl    8      3
# 156                architectural design    7      3
# 157                            postgres    7      3
# 158                 technical architect    7      3
# 159                          life cycle    6      3
# 160                               swift   78      2
# 161            configuration management   28      2
# 162                            selenium   27      2
# 163                    machine learning   26      2
# 164                         cocoa touch   25      2
# 165                          monitoring   23      2
# 166              object oriented design   22      2
# 167                                 jsp   21      2
# 168                                linq   19      2
# 169                                 pdf   19      2
# 170                   software engineer   19      2
# 171                    entity framework   18      2
# 172                  financial services   18      2
# 173     software development life cycle   16      2
# 174                     shell scripting   15      2
# 175                                 dns   14      2
# 176                             laravel   14      2
# 177                               plsql   14      2
# 178                  product management   14      2
# 179                               scala   13      2
# 180                  regression testing   12      2
# 181                       configuration   11      2
# 182                     problem solving   11      2
# 183                  production support   11      2
# 184                           scripting   11      2
# 185                       specification   11      2
# 186                                 dom   10      2
# 187                              drupal   10      2
# 188                                  pl   10      2
# 189                      system testing   10      2
# 190                      virtualization   10      2
# 191                   change management    9      2
# 192                     cloud computing    9      2
# 193                  manager technology    9      2
# 194                          mean stack    9      2
# 195                                 net    9      2
# 196            senior software engineer    9      2
# 197                 system architecture    9      2
# 198                      ui development    9      2
# 199                                bash    8      2
# 200                            big data    8      2
# 201                              c#.net    8      2
# 202                        optimization    8      2
# 203                          spring mvc    8      2
# 204                       web designing    8      2
# 205                                 wpf    8      2
# 206                         backbone.js    7      2
# 207                         codeigniter    7      2
# 208                                dbms    7      2
# 209                 development testing    7      2
# 210                              gradle    7      2
# 211                              hadoop    7      2
# 212                              joomla    7      2
# 213                                 jpa    7      2
# 214                       ms sql server    7      2
# 215                             parsing    7      2
# 216                   software services    7      2
# 217                      technical lead    7      2
# 218                               xhtml    7      2
# 219            application architecture    6      2
# 220                              bamboo    6      2
# 221                               basic    6      2
# 222                                 cms    6      2
# 223                                  go    6      2
# 224                              layout    6      2
# 225                             sensors    6      2
# 226                      .net framework    5      2
# 227                    active directory    5      2
# 228             application programming    5      2
# 229                       cloud foundry    5      2
# 230                                 com    5      2
# 231                 continuous delivery    5      2
# 232                           copyright    5      2
# 233                                  cv    5      2
# 234                      elastic search    5      2
# 235                               focus    5      2
# 236                              gaming    5      2
# 237                   hp data protector    5      2
# 238                                 iso    5      2
# 239                        linux kernel    5      2
# 240                    managed services    5      2
# 241                       mvc framework    5      2
# 242                            rabbitmq    5      2
# 243                                 seo    5      2
# 244                               spark    5      2
# 245                              vmware    5      2
# 246                                zend    5      2
# 247                  application design    4      2
# 248                   client management    4      2
# 249                             cordova    4      2
# 250                        data science    4      2
# 251                         eclipse ide    4      2
# 252                            ember.js    4      2
# 253                interpersonal skills    4      2
# 254                    iphone developer    4      2
# 255                         it services    4      2
# 256                             magento    4      2
# 257                              mentor    4      2
# 258                           messaging    4      2
# 259                            phonegap    4      2
# 260                 product engineering    4      2
# 261               responsive web design    4      2
# 262                               sales    4      2
# 263                         server side    4      2
# 264                  solution architect    4      2
# 265                           solutions    4      2
# 266                        sql database    4      2
# 267                             startup    4      2
# 268                                time    4      2
# 269                      android studio   24      1
# 270                             ansible   23      1
# 271                           microsoft   23      1
# 272                               cocoa   20      1
# 273                              puppet   20      1
# 274                       visual studio   20      1
# 275                           core data   19      1
# 276                  automation testing   18      1
# 277                      manual testing   18      1
# 278                              ms sql   17      1
# 279                           animation   14      1
# 280                            ethernet   14      1
# 281                                 iis   14      1
# 282                                chef   13      1
# 283                   embedded software   13      1
# 284                            hardware   11      1
# 285                        test scripts   11      1
# 286                automation framework   10      1
# 287                                 db2   10      1
# 288                            workflow   10      1
# 289                     data management    9      1
# 290                            embedded    9      1
# 291                          embedded c    9      1
# 292                  functional testing    9      1
# 293                             ios sdk    9      1
# 294                 performance testing    9      1
# 295                    software testing    9      1
# 296                   technical support    9      1
# 297                             telecom    9      1
# 298                    test engineering    9      1
# 299                       testing tools    9      1
# 300                                 usb    9      1
# 301                            wireless    9      1
# 302                             ado.net    8      1
# 303                application software    8      1
# 664                  technical analysis    2      1
# 665                    technical skills    2      1
# 666                           test data    2      1
# 667                            training    2      1
# 668                            triggers    2      1
# 669                              tuning    2      1
# 670                                uart    2      1
# 671                                 uds    2      1
# 672                unix shell scripting    2      1
# 673                            velocity    2      1
# 674                               views    2      1
# 675                        visual basic    2      1
# 676                                 vms    2      1
# 677                                 vpn    2      1
# 678                    web applications    2      1
# 679                        web crawling    2      1
# 680                         web testing    2      1
# 681                           webdynpro    2      1
# 682                           websphere    2      1
# 683                            wellness    2      1
# 684                      windows mobile    2      1
# 685                          windows os    2      1
# 686                      windows server    2      1
# 687                            winforms    2      1
# 688                                wlan    2      1
# 689                             xamarin    2      1
# 690                                xaml    2      1
# 691                                 yii    2      1
# 692                      zend framework    2      1

# %% [markdown]
# # Standard Skills (old)

# %%
# #
# ## Count Categories in matched job
# #

# df_category_count = df_match['Role'].value_counts().rename_axis('unique_values').reset_index(name='counts')
# df_category_count = df_category_count.head(3)
# df_category_count

# %%
# #
# ##
# ### Find Standard Skills for job
# ##
# #

# import math 

# df_standard_skill = pd.DataFrame(columns = ['Skill', 'Count'])
# total = 30
# if(len(df_category_count.index) == 1):
#     x = df_category_count['counts'][0]
#     y = 0
#     z = 0
        
# if(len(df_category_count.index) == 2):
#     x = df_category_count['counts'][0]
#     y = df_category_count['counts'][1]
#     z = 0
    
# if(len(df_category_count.index) == 3):
#     x = df_category_count['counts'][0]
#     y = df_category_count['counts'][1]
#     z = df_category_count['counts'][2]
    
# summation = x+y+z

# count = 0

# for x in df_category_count['unique_values']:
#     cat_input = df_category_count['counts'][count]
#     path = x.replace("/", ":")
#     df_cat = pd.read_csv('data/key skills count/role_' + path + '.csv')
#     df_cat = df_cat.rename(columns={'Unnamed: 0': 'Skill', '0': 'Count'})
    
#     selected = int(math.ceil((cat_input*total)/summation))
    
#     df_cat = df_cat.head(selected)
#     df_standard_skill = df_standard_skill.append(df_cat)
#     count = count + 1

        
# df_standard_skill = df_standard_skill.drop_duplicates(subset=['Skill'])
# df_standard_skill = df_standard_skill[~df_standard_skill['Skill'].isin(forbidden_category_skills)]
# df_standard_skill = df_standard_skill.reset_index(drop=True)
# df_standard_skill

# %% [markdown]
# # Common Skills (unused)

# %%
# df_common_skill = pd.DataFrame(columns = ['Skill', 'Count'])

# for x in roles:
#     path = x.replace("/", ":")
#     df_cat = pd.read_csv('data/key skills count/role_' + path + '.csv')
#     df_cat = df_cat.rename(columns={'Unnamed: 0': 'Skill', '0': 'Count'})
#     df_cat = df_cat.head(200)
#     df_common_skill = df_common_skill.append(df_cat)
    
# df_common_skill = df_common_skill['Skill'].value_counts().rename_axis('unique_values').reset_index(name='counts')
# df_common_skill = df_common_skill.drop_duplicates(subset=['unique_values'])
# df_common_skill = df_common_skill[~df_common_skill['unique_values'].isin(forbidden_category_skills)]
# df_common_skill = df_common_skill.reset_index(drop=True)
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#     display(df_common_skill)

# %%
# dash = extractSkill(df_match['Key Skills'])
# df_new = pd.DataFrame(dash.items(), columns = ['Job Title', 'Count']) 
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#     display(df_new)

# %%
# #
# ## exports counted elements to csv
# #
# df_count = pd.DataFrame.from_dict(elements_count, orient='index')
# df_count.to_csv('out.csv', index=True)
